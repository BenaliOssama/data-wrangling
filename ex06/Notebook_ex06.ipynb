# %%
import pandas as pd
import numpy as np

# %%
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Prediction'])
market_data
#np.random.randn(len(index), 1)
# Out:
# array([[ 0.45716348],
#        [ 2.17341834],
#        [-0.7184406 ],
#        ...,
#        [ 0.01667038],
#        [-0.74125003],
#        [-1.77055958]], shape=(1305, 1))

# %%
# Question 1: unstack the Ticker level into columns
unstacked = market_data.unstack()
print(unstacked.head(3).to_markdown())
# Out:
# | Date                |   ('Prediction', 'AAPL') |   ('Prediction', 'AMZN') |   ('Prediction', 'DAI') |   ('Prediction', 'FB') |   ('Prediction', 'GE') |
# |:--------------------|-------------------------:|-------------------------:|------------------------:|-----------------------:|-----------------------:|
# | 2021-01-01 00:00:00 |               -0.110628  |                -2.89095  |                0.297825 |               0.854689 |               0.328467 |
# | 2021-01-04 00:00:00 |               -3.05183   |                 0.677274 |                0.63396  |               2.27491  |              -0.683884 |
# | 2021-01-05 00:00:00 |               -0.0639676 |                 0.240699 |                0.762553 |              -1.23805  |               0.546396 |

# %%
# Question 2: plot all 5 time series
unstacked.plot(title='Stocks 2021')
# Out:
# <Axes: title={'center': 'Stocks 2021'}, xlabel='Date'>
