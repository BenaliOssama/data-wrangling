# %%
import pandas as pd
import numpy as np

# %%
# generate days
all_dates = pd.date_range('2021-01-01', '2021-12-15')
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

# generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

# create indexes
index_alt = pd.MultiIndex.from_product([all_dates, tickers], names=['Date', 'Ticker'])
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 3),
                        columns=['Open','Close','Close_Adjusted'])

print(market_data)

alternative_data = pd.DataFrame(index=index_alt,
                                data=np.random.randn(len(index_alt), 2),
                                columns=['Twitter','Reddit'])
print(alternative_data)
# Out:
#                        Open     Close  Close_Adjusted
# Date       Ticker
# 2021-01-01 AAPL    0.652674 -0.346890        0.785799
#            FB      0.946734  0.037265       -0.450522
#            GE     -0.747320  0.531053        0.491377
#            AMZN   -0.209398 -0.298437        1.152567
#            DAI     0.856186 -0.091258       -0.144179
# ...                     ...       ...             ...
# 2021-12-31 AAPL   -0.352620  0.460537        1.061468
#            FB     -0.186105  0.081818       -0.616964
#            GE      1.091913  0.495727       -0.908748
#            AMZN    0.450565  0.325708        0.991268
#            DAI    -0.508131 -1.672670        2.148984
#
# [1305 rows x 3 columns]
#                     Twitter    Reddit
# Date       Ticker
# 2021-01-01 AAPL    0.437596 -0.426016
#            FB      0.499768  0.250623
#            GE     -0.172118  0.162727
#            AMZN    0.688445  0.969059
#            DAI    -1.746431  1.241309
# ...                     ...       ...
# 2021-12-15 AAPL    0.108195 -0.860280
#            FB      0.780347  0.027993
#            GE     -0.622447  1.120818
#            AMZN   -0.856199  0.147105
#            DAI    -0.379518 -0.293095
#
# [1745 rows x 2 columns]

# %%
# Question 1: merge using the index as the key
merged = market_data.merge(alternative_data, how='left', left_index=True, right_index=True)
print(merged.shape)
print(merged.head())
# Out:
# (1305, 5)
#                        Open     Close  Close_Adjusted   Twitter    Reddit
# Date       Ticker
# 2021-01-01 AAPL    0.652674 -0.346890        0.785799  0.437596 -0.426016
#            FB      0.946734  0.037265       -0.450522  0.499768  0.250623
#            GE     -0.747320  0.531053        0.491377 -0.172118  0.162727
#            AMZN   -0.209398 -0.298437        1.152567  0.688445  0.969059
#            DAI     0.856186 -0.091258       -0.144179 -1.746431  1.241309

# %%
# Question 2: fill missing values with 0
filled = merged.fillna(0)
print(filled.head())
# Out:
#                        Open     Close  Close_Adjusted   Twitter    Reddit
# Date       Ticker
# 2021-01-01 AAPL    0.652674 -0.346890        0.785799  0.437596 -0.426016
#            FB      0.946734  0.037265       -0.450522  0.499768  0.250623
#            GE     -0.747320  0.531053        0.491377 -0.172118  0.162727
#            AMZN   -0.209398 -0.298437        1.152567  0.688445  0.969059
#            DAI     0.856186 -0.091258       -0.144179 -1.746431  1.241309
